# %%
import pandas as pd

df = pd.read_csv('original.csv')
df.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
columns = df.columns
print(columns)
# Out:
# Index(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(mcg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Vit_B6_(mg)',
#        'Vit_B12_(mcg)', 'Vit_A_IU', 'Vit_A_RAE', 'Vit_E_(mg)', 'Vit_D_mcg',
#        'Vit_D_IU', 'Vit_K_(mcg)', 'FA_Sat_(g)', 'FA_Mono_(g)', 'FA_Poly_(g)',
#        'Cholestrl_(mg)'],
#       dtype='object')

# %%
size = df.shape
print(size)
# Out:
# (8618, 36)

# %%
df.loc[1]
# Out:
# NDB_No                                 1002
# Shrt_Desc          BUTTER WHIPPED WITH SALT
# Water_(g)                             15.87
# Energ_Kcal                              717
# Protein_(g)                            0.85
# Lipid_Tot_(g)                         81.11
# Ash_(g)                                2.11
# Carbohydrt_(g)                         0.06
# Fiber_TD_(g)                              0
# Sugar_Tot_(g)                          0.06
# Calcium_(mg)                             24
# Iron_(mg)                              0.16
# Magnesium_(mg)                            2
# Phosphorus_(mg)                          23
# Potassium_(mg)                           26
# Sodium_(mg)                             659
# Zinc_(mg)                              0.05
# Copper_(mg)                           0.016
# Manganese_(mg)                        0.004
# Selenium_(mcg)                            1
# Vit_C_(mg)                                0
# ...

# %%
row_100 = df.loc[99]
print(row_100)
# Out:
# NDB_No                                  1111
# Shrt_Desc          MILK SHAKES THICK VANILLA
# Water_(g)                              74.45
# Energ_Kcal                               112
# Protein_(g)                             3.86
# Lipid_Tot_(g)                           3.03
# Ash_(g)                                 0.91
# Carbohydrt_(g)                         17.75
# Fiber_TD_(g)                               0
# Sugar_Tot_(g)                          17.75
# Calcium_(mg)                             146
# Iron_(mg)                                0.1
# Magnesium_(mg)                            12
# Phosphorus_(mg)                          115
# Potassium_(mg)                           183
# Sodium_(mg)                               95
# Zinc_(mg)                               0.39
# Copper_(mg)                            0.051
# Manganese_(mg)                         0.014
# Selenium_(mcg)                           2.3
# Vit_C_(mg)                                 0
# ...

# %%
df.loc[3:6]
# Out:
#    NDB_No         Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 3    1004       CHEESE BLUE      42.41         353        21.40
# 4    1005      CHEESE BRICK      41.11         371        23.24
# 5    1006       CHEESE BRIE      48.42         334        20.75
# 6    1007  CHEESE CAMEMBERT      51.80         300        19.80
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
# 5          27.68     2.70            0.45           0.0           0.45  ...
# 6          24.26     3.68            0.46           0.0           0.46  ...
#
#    Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  \
# 3     721.0      198.0        0.25        0.5      21.0          2.4
# 4    1080.0      292.0        0.26        0.5      22.0          2.5
# ...

# %%
df.loc[size[0]-5:]
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
cholestrol = df['Cholestrl_(mg)']

# %%
df[['Shrt_Desc','Water_(g)','Energ_Kcal']]
# Out:
#                        Shrt_Desc  Water_(g)  Energ_Kcal
# 0               BUTTER WITH SALT      15.87         717
# 1       BUTTER WHIPPED WITH SALT      15.87         717
# 2           BUTTER OIL ANHYDROUS       0.24         876
# 3                    CHEESE BLUE      42.41         353
# 4                   CHEESE BRICK      41.11         371
# ...                          ...        ...         ...
# 8613             MACKEREL SALTED      43.00         305
# 8614  SCALLOP (BAY&SEA) CKD STMD      70.25         111
# 8615                  SYRUP CANE      26.00         269
# 8616                   SNAIL RAW      79.20          90
# 8617            TURTLE GREEN RAW      78.50          89
#
# [8618 rows x 3 columns]

# %%
columns = columns.tolist()

# %%
g_columns = []
for c in columns:
    if c.endswith('(g)'):
        g_columns.append(c)

# %%
df_g = df[g_columns]
df_g[:3]
# Out:
#    Water_(g)  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0      15.87         0.85          81.11     2.11            0.06
# 1      15.87         0.85          81.11     2.11            0.06
# 2       0.24         0.28          99.48     0.00            0.00
#
#    Fiber_TD_(g)  Sugar_Tot_(g)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)
# 0           0.0           0.06      51.368       21.021        3.043
# 1           0.0           0.06      50.489       23.426        3.012
# 2           0.0           0.00      61.924       28.732        3.694

# %%
sodium_grams = df['Sodium_(mg)'] / 1000

# %%
sugar_milligrams = df['Sugar_Tot_(g)'] * 1000

# %%
print(sugar_milligrams)
# Out:
# 0          60.0
# 1          60.0
# 2           0.0
# 3         500.0
# 4         510.0
#          ...
# 8613        0.0
# 8614        0.0
# 8615    73200.0
# 8616        0.0
# 8617        0.0
# Name: Sugar_Tot_(g), Length: 8618, dtype: float64

# %%
grams_of_protein_per_gram_of_water = df['Protein_(g)'] / df['Water_(g)']
milligrams_of_calcium_and_iron = df['Calcium_(mg)'] + df['Iron_(mg)']

# %%
print(grams_of_protein_per_gram_of_water)
# Out:
# 0       0.053560
# 1       0.053560
# 2       1.166667
# 3       0.504598
# 4       0.565313
#           ...
# 8613    0.430233
# 8614    0.292384
# 8615    0.000000
# 8616    0.203283
# 8617    0.252229
# Length: 8618, dtype: float64

# %%
print(milligrams_of_calcium_and_iron)
# Out:
# 0        24.02
# 1        24.16
# 2         4.00
# 3       528.31
# 4       674.43
#          ...
# 8613     67.40
# 8614     10.58
# 8615     16.60
# 8616     13.50
# 8617    119.40
# Length: 8618, dtype: float64

# %%
protein = df['Protein_(g)'] * 2
fat = df['Lipid_Tot_(g)'] * (-0.75)
rating = protein + fat
print(rating)
# Out:
# 0      -59.1325
# 1      -59.1325
# 2      -74.0500
# 3       21.2450
# 4       24.2200
#          ...
# 8613    18.1750
# 8614    40.4500
# 8615     0.0000
# 8616    31.1500
# 8617    39.2250
# Length: 8618, dtype: float64

# %%
#normaliser les colonnes
max_protein = df['Protein_(g)'].max()
max_lipid = df['Lipid_Tot_(g)'].max()

normalized_protein = df['Protein_(g)'] / max_protein
normalized_lipid = df['Lipid_Tot_(g)'] / max_lipid

# %%
print(normalized_protein)
# Out:
# 0       0.009624
# 1       0.009624
# 2       0.003170
# 3       0.242301
# 4       0.263134
#           ...
# 8613    0.209466
# 8614    0.232563
# 8615    0.000000
# 8616    0.182292
# 8617    0.224185
# Name: Protein_(g), Length: 8618, dtype: float64

# %%
df['Normalized_protein'] = normalized_protein
df['Normalized_fat'] = normalized_lipid

# %%
df.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          81.11     2.11            0.06           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  Vit_K_(mcg)  FA_Sat_(g)  FA_Mono_(g)  \
# ...

# %%
df.sort_values("Norm_Nutr_Index",inplace=True,ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-825a0d21ea7a> in <module>
# ----> 1 df.sort_values("Norm_Nutr_Index",inplace=True,ascending=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Norm_Nutr_Index'
