# %%
import pandas as pd

# %%
fandango = pd.read_csv('fandango_score_comparaison.csv')
fandango.head(2)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0     3.70           4.3  ...       3.90            3.5                 4.5
# 1     4.25           4.0  ...       3.55            4.5                 4.0
#
#    Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                    3.5                         3.5              4.0
# 1                    3.5                         4.0              3.5
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# ...

# %%
print(fandango.index)
# Out:
# RangeIndex(start=0, stop=146, step=1)

# %%
first_last = fandango.iloc[[0,fandango.shape[0]-1]]

# %%
first_last
# Out:
#                                    FILM  RottenTomatoes  RottenTomatoes_User  \
# 0        Avengers: Age of Ultron (2015)              74                   86
# 145  Kumiko, The Treasure Hunter (2015)              87                   63
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0            66              7.1   7.8             5.0                   4.5
# 145          68              6.4   6.7             3.5                   3.5
#
#      RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0       3.70          4.30  ...       3.90            3.5                 4.5
# 145     4.35          3.15  ...       3.35            4.5                 3.0
#
#      Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                      3.5                         3.5              4.0
# 145                    3.5                         3.0              3.5
#
# ...

# %%
fandango_film = fandango.set_index('FILM',drop=False)
fandango_film.index
# Out:
# Index(['Avengers: Age of Ultron (2015)', 'Cinderella (2015)', 'Ant-Man (2015)',
#        'Do You Believe? (2015)', 'Hot Tub Time Machine 2 (2015)',
#        'The Water Diviner (2015)', 'Irrational Man (2015)', 'Top Five (2014)',
#        'Shaun the Sheep Movie (2015)', 'Love & Mercy (2015)',
#        ...
#        'The Woman In Black 2 Angel of Death (2015)', 'Danny Collins (2015)',
#        'Spare Parts (2015)', 'Serena (2015)', 'Inside Out (2015)',
#        'Mr. Holmes (2015)', ''71 (2015)', 'Two Days, One Night (2014)',
#        'Gett: The Trial of Viviane Amsalem (2015)',
#        'Kumiko, The Treasure Hunter (2015)'],
#       dtype='object', name='FILM', length=146)

# %%
list_movies = ['Ant-Man (2015)','Cinderella (2015)','Danny Collins (2015)']
fandango_film.loc[list_movies]
# Out:
#                                       FILM  RottenTomatoes  \
# FILM
# Ant-Man (2015)              Ant-Man (2015)              80
# Cinderella (2015)        Cinderella (2015)              85
# Danny Collins (2015)  Danny Collins (2015)              77
#
#                       RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# FILM
# Ant-Man (2015)                         90          64              8.1   7.8
# Cinderella (2015)                      80          67              7.5   7.1
# Danny Collins (2015)                   75          58              7.1   7.1
#
#                       Fandango_Stars  Fandango_Ratingvalue  RT_norm  \
# FILM
# Ant-Man (2015)                   5.0                   4.5     4.00
# Cinderella (2015)                5.0                   4.5     4.25
# Danny Collins (2015)             4.0                   4.0     3.85
#
#                       RT_user_norm  ...  IMDB_norm  RT_norm_round  \
# FILM                                ...
# ...

# %%
types = fandango_film.dtypes
float_columns = types[types.values == 'float64']
float_columns
# Out:
# Metacritic_User               float64
# IMDB                          float64
# Fandango_Stars                float64
# Fandango_Ratingvalue          float64
# RT_norm                       float64
# RT_user_norm                  float64
# Metacritic_norm               float64
# Metacritic_user_nom           float64
# IMDB_norm                     float64
# RT_norm_round                 float64
# RT_user_norm_round            float64
# Metacritic_norm_round         float64
# Metacritic_user_norm_round    float64
# IMDB_norm_round               float64
# Fandango_Difference           float64
# dtype: object

# %%
float_df = fandango_film[float_columns.index]
float_df
# Out:
#                                            Metacritic_User  IMDB  \
# FILM
# Avengers: Age of Ultron (2015)                         7.1   7.8
# Cinderella (2015)                                      7.5   7.1
# Ant-Man (2015)                                         8.1   7.8
# Do You Believe? (2015)                                 4.7   5.4
# Hot Tub Time Machine 2 (2015)                          3.4   5.1
# ...                                                    ...   ...
# Mr. Holmes (2015)                                      7.9   7.4
# '71 (2015)                                             7.5   7.2
# Two Days, One Night (2014)                             8.8   7.4
# Gett: The Trial of Viviane Amsalem (2015)              7.3   7.8
# Kumiko, The Treasure Hunter (2015)                     6.4   6.7
#
#                                            Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)                        5.0
# ...

# %%
#ecart type
import numpy as np

# %%
ecartype_columns = float_df.apply(lambda x: np.std(x))
print(ecartype_columns)
# Out:
# Metacritic_User               1.505529
# IMDB                          0.955447
# Fandango_Stars                0.538532
# Fandango_Ratingvalue          0.501106
# RT_norm                       1.503265
# RT_user_norm                  0.997787
# Metacritic_norm               0.972522
# Metacritic_user_nom           0.752765
# IMDB_norm                     0.477723
# RT_norm_round                 1.509404
# RT_user_norm_round            1.003559
# Metacritic_norm_round         0.987561
# Metacritic_user_norm_round    0.785412
# IMDB_norm_round               0.501043
# Fandango_Difference           0.152141
# dtype: float64

# %%
exo_df = float_df.apply(lambda x: x/2)
exo_df.head()
# Out:
#                                 Metacritic_User  IMDB  Fandango_Stars  \
# FILM
# Avengers: Age of Ultron (2015)             3.55  3.90            2.50
# Cinderella (2015)                          3.75  3.55            2.50
# Ant-Man (2015)                             4.05  3.90            2.50
# Do You Believe? (2015)                     2.35  2.70            2.50
# Hot Tub Time Machine 2 (2015)              1.70  2.55            1.75
#
#                                 Fandango_Ratingvalue  RT_norm  RT_user_norm  \
# FILM
# Avengers: Age of Ultron (2015)                  2.25    1.850          2.15
# Cinderella (2015)                               2.25    2.125          2.00
# Ant-Man (2015)                                  2.25    2.000          2.25
# Do You Believe? (2015)                          2.25    0.450          2.10
# Hot Tub Time Machine 2 (2015)                   1.50    0.350          0.70
#
#                                 Metacritic_norm  Metacritic_user_nom  \
# ...

# %%
result_apply_ligne = float_df[['RT_user_norm','Metacritic_user_nom']].apply(lambda x: np.mean(x),axis=1)
result_apply_ligne
# Out:
# FILM
# Avengers: Age of Ultron (2015)               3.925
# Cinderella (2015)                            3.875
# Ant-Man (2015)                               4.275
# Do You Believe? (2015)                       3.275
# Hot Tub Time Machine 2 (2015)                1.550
#                                              ...
# Mr. Holmes (2015)                            3.925
# '71 (2015)                                   3.925
# Two Days, One Night (2014)                   4.150
# Gett: The Trial of Viviane Amsalem (2015)    3.850
# Kumiko, The Treasure Hunter (2015)           3.175
# Length: 146, dtype: float64
